# %%
import matplotlib.pyplot as plt
import nest 
import nest.voltage_trace

nest.set_verbosity("M_WARNING")
nest.ResetKernel()
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.8.0
#  Built: Jan 27 2025 08:17:55
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %% [markdown]
# # One neuron model

# %%
neuron = nest.Create("iaf_psc_alpha") # LIF model
voltmeter = nest.Create("voltmeter")

neuron.I_e = 376.0

nest.Connect(voltmeter, neuron)

nest.Simulate(1000.0) # 1000 millisecond desired simulation time

# %%
nest.voltage_trace.from_device(voltmeter)
plt.show()

# %% [markdown]
# # Two neuron model

# %%
neuron_1 = nest.Create("iaf_psc_alpha")
neuron_2 = nest.Create("iaf_psc_alpha")
voltmeter_two_neurons = nest.Create("voltmeter")

# %%
print(neuron_1)
# Out:
# NodeCollection(metadata=None, model=iaf_psc_alpha, size=1, first=3)

# %%
print(neuron_2)
# Out:
# NodeCollection(metadata=None, model=iaf_psc_alpha, size=1, first=4)

# %%
print(voltmeter_two_neurons)
# Out:
# NodeCollection(metadata=None, model=voltmeter, size=1, first=5)

# %%
neuron_1.I_e = 376.0

# %%
weight = 20.0 # synaptic weight - strength of connection between 2 nodess
delay = 1.0

# %%
nest.Connect(neuron_1, neuron_2, syn_spec={"weight": weight, "delay": delay})
nest.Connect(voltmeter, neuron_1)
nest.Connect(voltmeter, neuron_2)

# %%
nest.Simulate(1000.0)

# %%
nest.voltage_trace.from_device(voltmeter)
plt.show()
